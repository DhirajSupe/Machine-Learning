# %% [markdown]
# # visualization Assignment

# %% [markdown]
# ### 1) Perform analysis on house data . Must include
#
# ### a) Scatter plot
#
# ### b) Histogram
#
# ### c) Bar and pie chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
house = pd.read_csv("house.csv")

# %%
house.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house_sample = house.head(2000)

# %%
print(house_sample)
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 0     7129300520  20141013T000000  221900.0         3       1.00         1180
# 1     6414100192  20141209T000000  538000.0         3       2.25         2570
# 2     5631500400  20150225T000000  180000.0         2       1.00          770
# 3     2487200875  20141209T000000  604000.0         4       3.00         1960
# 4     1954400510  20150218T000000  510000.0         3       2.00         1680
# ...          ...              ...       ...       ...        ...          ...
# 1995  1022059082  20140508T000000  307000.0         3       1.75         1890
# 1996   179000350  20141105T000000  194000.0         3       1.50         1010
# 1997  3915500045  20141114T000000  180000.0         3       1.00         1010
# 1998  3578400030  20140718T000000  465000.0         4       2.25         2340
# 1999  9346700320  20150323T000000  722500.0         4       2.50         2460
#
# ...

# %%
house_sample.drop("date",axis=1,inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
house_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2000 non-null   int64
#  1   price          2000 non-null   float64
#  2   bedrooms       2000 non-null   int64
#  3   bathrooms      2000 non-null   float64
#  4   sqft_living    2000 non-null   int64
#  5   sqft_lot       2000 non-null   int64
#  6   floors         2000 non-null   float64
#  7   waterfront     2000 non-null   int64
#  8   view           2000 non-null   int64
#  9   condition      2000 non-null   int64
#  10  grade          2000 non-null   int64
#  11  sqft_above     2000 non-null   int64
#  12  sqft_basement  2000 non-null   int64
#  13  yr_built       2000 non-null   int64
#  14  yr_renovated   2000 non-null   int64
#  15  zipcode        2000 non-null   int64
#  16  lat            2000 non-null   float64
# ...

# %%
house_sample.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000  0.024990  0.029031   0.037330     0.024917 -0.100278
# price          0.024990  1.000000  0.307589   0.515670     0.694433  0.073064
# bedrooms       0.029031  0.307589  1.000000   0.546148     0.575898  0.032130
# bathrooms      0.037330  0.515670  0.546148   1.000000     0.759214  0.037019
# sqft_living    0.024917  0.694433  0.575898   0.759214     1.000000  0.100977
# sqft_lot      -0.100278  0.073064  0.032130   0.037019     0.100977  1.000000
# floors         0.021982  0.269867  0.226438   0.491617     0.394762 -0.006974
# waterfront    -0.006554  0.325342 -0.016988   0.091868     0.113370  0.015929
# view           0.013691  0.444642  0.064756   0.179904     0.298101  0.090924
# condition     -0.058786  0.056121  0.014368  -0.088709    -0.033451 -0.000780
# grade          0.039779  0.631838  0.386047   0.666194     0.771779  0.053966
# ...

# %% [markdown]
# # Line plot

# %%
plt.figure()
sns.lineplot(house_sample['bedrooms'],house_sample['price'])
plt.show()

# %%
plt.figure()
sns.scatterplot(data =house_sample,x = "bedrooms",y = "price")
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.figure()
sns.distplot(house_sample["bedrooms"])
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
plt.figure()
plt.bar(house_sample["bedrooms"],house_sample["price"])
plt.show()

# %% [markdown]
# ## PIE Chart

# %%
plt.figure(figsize=(8,8))
house_sample['floors'].value_counts().plot(kind = 'pie',autopct = '%1.1f%%')
plt.show()
